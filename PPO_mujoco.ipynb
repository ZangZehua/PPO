# %%
# !nvidia-smi
# Out:
# Sun Feb 27 14:48:15 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !apt-get install -y \
    libgl1-mesa-dev \
    libgl1-mesa-glx \
    libglew-dev \
    libosmesa6-dev \
    software-properties-common

# !apt-get install -y patchelf
# !pip install gym
# !pip install free-mujoco-py
# !pip install tensorboardX
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libglew-dev is already the newest version (2.0.0-5).
# libgl1-mesa-dev is already the newest version (20.0.8-0ubuntu1~18.04.1).
# libgl1-mesa-glx is already the newest version (20.0.8-0ubuntu1~18.04.1).
# libosmesa6-dev is already the newest version (20.0.8-0ubuntu1~18.04.1).
# software-properties-common is already the newest version (0.96.24.32.18).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# patchelf is already the newest version (0.9-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym) (1.21.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# Requirement already satisfied: free-mujoco-py in /usr/local/lib/python3.7/dist-packages (2.1.6)
# Requirement already satisfied: fasteners==0.15 in /usr/local/lib/python3.7/dist-packages (from free-mujoco-py) (0.15)
# Requirement already satisfied: imageio<3.0.0,>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from free-mujoco-py) (2.16.0)
# Requirement already satisfied: Cython<0.30.0,>=0.29.24 in /usr/local/lib/python3.7/dist-packages (from free-mujoco-py) (0.29.28)
# Requirement already satisfied: numpy<2.0.0,>=1.21.3 in /usr/local/lib/python3.7/dist-packages (from free-mujoco-py) (1.21.5)
# Requirement already satisfied: cffi<2.0.0,>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from free-mujoco-py) (1.15.0)
# Requirement already satisfied: glfw<2.0.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from free-mujoco-py) (1.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fasteners==0.15->free-mujoco-py) (1.15.0)
# Requirement already satisfied: monotonic>=0.1 in /usr/local/lib/python3.7/dist-packages (from fasteners==0.15->free-mujoco-py) (1.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi<2.0.0,>=1.15.0->free-mujoco-py) (2.21)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.7/dist-packages (from imageio<3.0.0,>=2.9.0->free-mujoco-py) (9.0.1)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.7/dist-packages (2.5)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.5)

# %%
# 挂载google drive
from google.colab import drive

drive.mount('/content/drive')
# 更改当前目录到项目目录
import os

os.chdir("/content/drive/MyDrive/projects/PPO_mujoco")
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/projects/PPO_mujoco

# %%
import mujoco_py
import gym  # gym must to be imported behind mujoco_py
import os
import math
import datetime
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

from collections import deque
from tensorboardX.writer import SummaryWriter

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# 虽然不知道这个py是干什么的，但是感觉很厉害的样子，暂且先留着吧
# from https://github.com/joschu/modular_rl
# http://www.johndcook.com/blog/standard_deviation/
class RunningStat(object):
    def __init__(self, shape):
        self._n = 0
        self._M = np.zeros(shape)
        self._S = np.zeros(shape)

    def push(self, x):
        x = np.asarray(x)
        assert x.shape == self._M.shape
        self._n += 1
        if self._n == 1:
            self._M[...] = x
        else:
            oldM = self._M.copy()
            self._M[...] = oldM + (x - oldM) / self._n
            self._S[...] = self._S + (x - oldM) * (x - self._M)

    @property
    def n(self):
        return self._n

    @property
    def mean(self):
        return self._M

    @property
    def var(self):
        return self._S / (self._n - 1) if self._n > 1 else np.square(self._M)

    @property
    def std(self):
        return np.sqrt(self.var)

    @property
    def shape(self):
        return self._M.shape


class ZFilter:
    """
    y = (x-mean)/std
    using running estimates of mean,std
    """

    def __init__(self, shape, demean=True, destd=True, clip=10.0):
        self.demean = demean
        self.destd = destd
        self.clip = clip
        self.rs = RunningStat(shape)

    def __call__(self, x, update=True):
        if update: self.rs.push(x)
        if self.demean:
            x = x - self.rs.mean
        if self.destd:
            x = x / (self.rs.std + 1e-8)
        if self.clip:
            x = np.clip(x, -self.clip, self.clip)
        return x

    def output_shape(self, input_space):
        return input_space.shape

# %%
# network 
class Actor(nn.Module):
    def __init__(self, input_dim, action_dim, hidden_dim):
        self.input_dim = input_dim
        self.action_dim = action_dim
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, action_dim)
        self.fc3.weight.data.mul_(0.1)
        self.fc3.bias.data.mul_(0.0)

    def forward(self, x):
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        mu = self.fc3(x)
        logstd = torch.zeros_like(mu)
        std = torch.exp(logstd)
        return mu, std, logstd


class Critic(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 1)
        self.fc3.weight.data.mul_(0.1)
        self.fc3.bias.data.mul_(0.0)

    def forward(self, x):
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        v = self.fc3(x)
        return v

# %%
def get_action(mu, std):
    action = torch.normal(mu, std)
    action = action.data.numpy()
    return action


def log_density(x, mu, std, logstd):
    var = std.pow(2)
    log_density = -(x - mu).pow(2) / (2 * var) \
                  - 0.5 * math.log(2 * math.pi) - logstd

    return log_density.sum(1, keepdim=True)


def flat_grad(grads):
    grad_flatten = []
    for grad in grads:
        grad_flatten.append(grad.view(-1))
    grad_flatten = torch.cat(grad_flatten)
    return grad_flatten


def flat_hessian(hessians):
    hessians_flatten = []
    for hessian in hessians:
        hessians_flatten.append(hessian.contiguous().view(-1))
    hessians_flatten = torch.cat(hessians_flatten).data
    return hessians_flatten


def flat_params(model):
    params = []
    for param in model.parameters():
        params.append(param.data.view(-1))
    params_flatten = torch.cat(params)
    return params_flatten


def update_model(model, new_params):
    index = 0
    for params in model.parameters():
        params_length = len(params.view(-1))
        new_param = new_params[index: index + params_length]
        new_param = new_param.view(params.size())
        params.data.copy_(new_param)
        index += params_length


def kl_divergence(new_actor, old_actor, states):
    mu, std, logstd = new_actor(torch.Tensor(states))
    mu_old, std_old, logstd_old = old_actor(torch.Tensor(states))
    mu_old = mu_old.detach()
    std_old = std_old.detach()
    logstd_old = logstd_old.detach()

    # kl divergence between old policy and new policy : D( pi_old || pi_new )
    # pi_old -> mu0, logstd0, std0 / pi_new -> mu, logstd, std
    # be careful of calculating KL-divergence. It is not symmetric metric
    kl = logstd_old - logstd + (std_old.pow(2) + (mu_old - mu).pow(2)) / (2.0 * std.pow(2)) - 0.5

    return kl.sum(1, keepdim=True)

# %%
class PPO:
    def __init__(self, device, input_dim, action_dim, hidden_dim, actor_lr, critic_lr, l2_rate, gamma, lamda, batch_size, clip_param, running_state):
        self.device = device
        self.actor = Actor(input_dim, action_dim, hidden_dim).to(device)
        self.critic = Critic(input_dim, hidden_dim).to(device)
        self.actor_optim = optim.Adam(self.actor.parameters(), lr=actor_lr)
        self.critic_optim = optim.Adam(self.critic.parameters(), lr=critic_lr, weight_decay=l2_rate)
        self.gamma = gamma
        self.lamda = lamda
        self.batch_size = batch_size
        self.clip_param = clip_param
        self.running_state = running_state

    def get_state(self, observation):
        state = running_state(observation)
        state = torch.Tensor(state).unsqueeze(0)
        return state

    def select_action(self, state):
        mu, std, _ = self.actor(state.to(self.device))
        action = torch.normal(mu, std)
        action = action.data.cpu().numpy()[0]
        return action

    def log_density(self, x, mu, std, logstd):
        var = std.pow(2)
        logdensity = -(x - mu).pow(2) / (2 * var) \
                      - 0.5 * math.log(2 * math.pi) - logstd

        return logdensity.sum(1, keepdim=True)

    def train_model(self, memory):
        memory = np.array(memory)
        states = torch.Tensor(np.vstack(memory[:, 0])).to(self.device)
        actions = torch.Tensor(list(memory[:, 1])).to(self.device)
        rewards = torch.Tensor(list(memory[:, 2])).to(self.device)
        masks = torch.Tensor(list(memory[:, 3])).to(self.device)
        values = self.critic(states)
        # ----------------------------
        # step 1: get returns and GAEs and log probability of old policy
        returns, advants = self.get_gae(rewards, masks, values)
        mu, std, logstd = self.actor(states)
        old_policy = self.log_density(actions, mu, std, logstd).detach()
        criterion = torch.nn.MSELoss()
        n = len(states)
        arr = np.arange(n)
        # ----------------------------
        # step 2: get value loss and actor loss and update actor & critic
        for epoch in range(10):
            np.random.shuffle(arr)
            for i in range(n // self.batch_size):
                batch_index = arr[self.batch_size * i: self.batch_size * (i + 1)]
                batch_index = torch.LongTensor(batch_index)
                # print("batch_index ", batch_index)
                states_samples = states[batch_index]
                returns_samples = returns.unsqueeze(1)[batch_index]
                advants_samples = advants.unsqueeze(1)[batch_index]
                actions_samples = actions[batch_index]
                old_policy_samples = old_policy[batch_index]
                loss, ratio = self.surrogate_loss(advants_samples, states_samples, old_policy_samples, actions_samples)

                values = self.critic(states_samples)
                critic_loss = criterion(values, returns_samples)
                self.critic_optim.zero_grad()
                critic_loss.backward()
                self.critic_optim.step()

                clipped_ratio = torch.clamp(ratio, 1.0 - self.clip_param, 1.0 + self.clip_param)
                clipped_loss = clipped_ratio * advants_samples
                actor_loss = -torch.min(loss, clipped_loss).mean()
                self.actor_optim.zero_grad()
                actor_loss.backward()
                self.actor_optim.step()

    def get_gae(self, rewards, masks, values):
        returns = torch.zeros_like(rewards).to(self.device)
        advants = torch.zeros_like(rewards).to(self.device)

        running_returns = 0
        previous_value = 0
        running_advants = 0

        for t in reversed(range(0, len(rewards))):
            running_returns = rewards[t] + self.gamma * running_returns * masks[t]
            running_tderror = rewards[t] + self.gamma * previous_value * masks[t] - values.data[t]
            running_advants = running_tderror + self.gamma * self.lamda * running_advants * masks[t]

            returns[t] = running_returns
            previous_value = values.data[t]
            advants[t] = running_advants

        advants = (advants - advants.mean()) / advants.std()
        return returns, advants

    def surrogate_loss(self, advants, states, old_policy, actions):
        mu, std, logstd = self.actor(states)
        new_policy = self.log_density(actions, mu, std, logstd)

        ratio = torch.exp(new_policy - old_policy)
        surrogate = ratio * advants
        return surrogate, ratio

# %%
class Config:
    # common config
    random_seed = 500  # set random seed if required (0 = no random seed)
    train_time = str(datetime.datetime.now().replace(microsecond=0).strftime("%Y-%m-%d-%H-%M-%S"))

    # cuda config
    device = torch.device('cpu')
    device_name = "cpu"
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
        torch.cuda.empty_cache()
        device_name = torch.cuda.get_device_name(device)

    # network config
    hidden_dim = 64
    critic_lr = 0.0003
    actor_lr = 0.0003
    # env config
    env_name = "Hopper-v2"

    # ppo config
    max_step = 10000000
    gamma = 0.99
    lamda = 0.98
    batch_size = 64
    l2_rate = 0.001
    max_kl = 0.01
    clip_param = 0.2
    update_interval = 2000
    update_episode = 50

    # log config
    if not os.path.exists("runs"):
        os.mkdir("runs")
    if not os.path.exists("runs/" + env_name):
        os.mkdir("runs/" + env_name)
    if not os.path.exists("saved"):
        os.mkdir("saved")
    if not os.path.exists("saved/model"):
        os.mkdir("saved/model")

# %%
config = Config()

env = gym.make(config.env_name)
env.seed(config.random_seed)
torch.manual_seed(config.random_seed)
print("==========" * 5)
print("Train env: {}, device: {}".format(config.env_name, config.device_name))
print("==========" * 5)
input_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
running_state = ZFilter(env.observation_space.shape, clip=5)

reward_writer = SummaryWriter('runs/' + config.env_name + "/train_reward_" + config.train_time)
ppo_agent = PPO(config.device, input_dim, action_dim, config.hidden_dim,
                config.actor_lr, config.critic_lr, config.l2_rate, config.gamma, config.lamda, config.batch_size, config.clip_param,
                running_state)

episode = 0
step = 0
all_rewards = []
episode_reward = 0
memory = deque()
start_time = datetime.datetime.now().replace(microsecond=0)
observation = env.reset()
episodes = 0
all_steps = 0

for iter in range(15000):
    ppo_agent.actor.eval(), ppo_agent.critic.eval()
    memory = deque()
    
    steps = 0
    scores = []
    while steps < 2048:
        episodes += 1
        state = env.reset()
        state = ppo_agent.get_state(state)
        score = 0
        for _ in range(10000):

            steps += 1
            action = ppo_agent.select_action(state)
            next_state, reward, done, _ = env.step(action)
            next_state = ppo_agent.get_state(next_state)

            if done:
                mask = 0
            else:
                mask = 1

            memory.append([state, action, reward, mask])

            score += reward
            state = next_state

            if done:
                break
        scores.append(score)
    all_steps += steps
    print("steps: {}, all step: {}".format(steps, all_steps))
    score_avg = np.mean(scores)
    print('{} episode score is {:.2f}'.format(episodes, score_avg))
    ppo_agent.actor.train(), ppo_agent.critic.train()
    ppo_agent.train_model(memory)

# ppo_agent.actor.eval(), ppo_agent.critic.eval()
# while step < config.max_step:
#     state = ppo_agent.get_state(observation)
#     action = ppo_agent.select_action(state)
#     next_state, reward, done, _ = env.step(action)
#     step += 1
#     episode_reward += reward
#     if done:
#         next_state = env.reset()
#         all_rewards.append(episode_reward)
#         episode += 1
#         episode_reward = 0
#         mask = 0
#     else:
#         mask = 1
#     memory.append([state, action, reward, mask])
#     state = next_state
#     if done and episode % config.update_episode == 0:
#         ppo_agent.actor.train(), ppo_agent.critic.train()
#         epoch_time = datetime.datetime.now().replace(microsecond=0)
#         print("step: {}, reward: {:.2f}, episode:{}, train time: {}".format(
#             step, np.mean(all_rewards[-5:]), episode, epoch_time - start_time))
#         ppo_agent.train_model(memory)  # update network
#         memory = deque()  # reset memory
#         torch.save(ppo_agent.actor.state_dict(), "saved/model/" + config.env_name + "_actor_" + config.train_time)
#         torch.save(ppo_agent.actor.state_dict(), "saved/model" + config.env_name + "_critic_" + config.train_time)
#         ppo_agent.actor.eval(), ppo_agent.critic.eval()
# Out:
# ==================================================
# Train env: Hopper-v2, device: Tesla T4
# ==================================================
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# steps: 2059, all step: 2059
# 107 episode score is 16.76
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# steps: 2091, all step: 4150
# 179 episode score is 31.02
# steps: 2074, all step: 6224
# 235 episode score is 51.24
# steps: 2049, all step: 8273
# 270 episode score is 96.02
# steps: 2085, all step: 10358
# 300 episode score is 125.71
# steps: 2134, all step: 12492
# 328 episode score is 142.48
# steps: 2095, all step: 14587
# 353 episode score is 176.43
# steps: 2050, all step: 16637
# 375 episode score is 198.98
# steps: 2098, all step: 18735
# 397 episode score is 205.68
# steps: 2059, all step: 20794
# 421 episode score is 187.12
# steps: 2081, all step: 22875
# 443 episode score is 208.46
# steps: 2114, all step: 24989
# 465 episode score is 216.34
# steps: 2120, all step: 27109
# 487 episode score is 217.67
# steps: 2109, all step: 29218
# 509 episode score is 210.09
# steps: 2052, all step: 31270
# 530 episode score is 219.21
# steps: 2085, all step: 33355
# 552 episode score is 211.29
# steps: 2123, all step: 35478
# 574 episode score is 215.59
# steps: 2122, all step: 37600
# 596 episode score is 220.24
# steps: 2136, all step: 39736
# 618 episode score is 220.33
# steps: 2122, all step: 41858
# 640 episode score is 221.78
# steps: 2107, all step: 43965
# 661 episode score is 229.85
# steps: 2057, all step: 46022
# 682 episode score is 225.75
# steps: 2094, all step: 48116
# 703 episode score is 227.77
# steps: 2072, all step: 50188
# 724 episode score is 226.52
# steps: 2101, all step: 52289
# 744 episode score is 243.94
# steps: 2088, all step: 54377
# 763 episode score is 258.25
# steps: 2149, all step: 56526
# 782 episode score is 269.94
# steps: 2059, all step: 58585
# 800 episode score is 273.46
# steps: 2106, all step: 60691
# 818 episode score is 286.77
# steps: 2130, all step: 62821
# 836 episode score is 288.04
# steps: 2130, all step: 64951
# 853 episode score is 316.89
# steps: 2159, all step: 67110
# 871 episode score is 300.09
# steps: 2058, all step: 69168
# 887 episode score is 329.88
# steps: 2177, all step: 71345
# 904 episode score is 330.55
# steps: 2117, all step: 73462
# 920 episode score is 345.65
# steps: 2115, all step: 75577
# 936 episode score is 349.45
# steps: 2151, all step: 77728
# 952 episode score is 358.27
# steps: 2067, all step: 79795
# 967 episode score is 369.55
# steps: 2184, all step: 81979
# 983 episode score is 369.14
# steps: 2058, all step: 84037
# 998 episode score is 368.79
# steps: 2152, all step: 86189
# 1014 episode score is 357.17
# steps: 2084, all step: 88273
# 1029 episode score is 381.86
# steps: 2091, all step: 90364
# 1044 episode score is 387.34
# steps: 2067, all step: 92431
# 1059 episode score is 382.85
# steps: 2108, all step: 94539
# 1074 episode score is 393.52
# steps: 2113, all step: 96652
# 1089 episode score is 397.39
# steps: 2126, all step: 98778
# 1104 episode score is 400.64
# steps: 2103, all step: 100881
# 1119 episode score is 398.46
# steps: 2104, all step: 102985
# 1134 episode score is 397.17
# steps: 2150, all step: 105135
# 1149 episode score is 406.60
# steps: 2161, all step: 107296
# 1164 episode score is 411.26
# steps: 2176, all step: 109472
# 1180 episode score is 385.36
# steps: 2165, all step: 111637
# 1195 episode score is 412.57
# steps: 2159, all step: 113796
# 1210 episode score is 411.17
# steps: 2189, all step: 115985
# 1225 episode score is 417.87
# steps: 2174, all step: 118159
# 1240 episode score is 417.83
# steps: 2066, all step: 120225
# 1254 episode score is 424.27
# steps: 2164, all step: 122389
# 1269 episode score is 415.89
# steps: 2068, all step: 124457
# 1284 episode score is 394.54
# steps: 2174, all step: 126631
# 1299 episode score is 417.20
# steps: 2056, all step: 128687
# 1313 episode score is 422.83
# steps: 2058, all step: 130745
# 1327 episode score is 422.52
# steps: 2099, all step: 132844
# 1341 episode score is 437.09
# steps: 2136, all step: 134980
# 1356 episode score is 407.31
# steps: 2101, all step: 137081
# 1370 episode score is 434.72
# steps: 2177, all step: 139258
# 1385 episode score is 417.80
# steps: 2116, all step: 141374
# 1399 episode score is 434.42
# steps: 2108, all step: 143482
# 1412 episode score is 480.95
# steps: 2189, all step: 145671
# 1426 episode score is 458.61
# steps: 2110, all step: 147781
# 1439 episode score is 477.60
# steps: 2234, all step: 150015
# 1452 episode score is 523.16
# steps: 2190, all step: 152205
# 1464 episode score is 557.81
# steps: 2193, all step: 154398
# 1476 episode score is 549.04
# steps: 2207, all step: 156605
# 1488 episode score is 565.80
# steps: 2228, all step: 158833
# 1499 episode score is 624.54
# steps: 2181, all step: 161014
# 1510 episode score is 618.88
# steps: 2164, all step: 163178
# 1521 episode score is 605.33
# steps: 2060, all step: 165238
# 1531 episode score is 639.02
# steps: 2139, all step: 167377
# 1542 episode score is 606.71
# steps: 2107, all step: 169484
# 1552 episode score is 651.94
# steps: 2181, all step: 171665
# 1563 episode score is 612.82
# steps: 2197, all step: 173862
# 1575 episode score is 544.50
# steps: 2058, all step: 175920
# 1585 episode score is 635.11
# steps: 2210, all step: 178130
# 1596 episode score is 614.18
# steps: 2218, all step: 180348
# 1607 episode score is 632.75
# steps: 2058, all step: 182406
# 1617 episode score is 636.50
# steps: 2228, all step: 184634
# 1628 episode score is 622.94
# steps: 2283, all step: 186917
# 1639 episode score is 638.72
# steps: 2204, all step: 189121
# 1649 episode score is 677.68
# steps: 2107, all step: 191228
# 1658 episode score is 729.08
# steps: 2201, all step: 193429
# 1668 episode score is 683.88
# steps: 2199, all step: 195628
# 1678 episode score is 687.61
# steps: 2258, all step: 197886
# 1688 episode score is 692.52
# steps: 2159, all step: 200045
# 1697 episode score is 750.39
# steps: 2239, all step: 202284
# 1707 episode score is 704.29
# steps: 2059, all step: 204343
# 1716 episode score is 709.01
# steps: 2157, all step: 206500
# 1726 episode score is 655.95
# steps: 2309, all step: 208809
# 1735 episode score is 805.00
# steps: 2050, all step: 210859
# 1743 episode score is 811.01
# steps: 2278, all step: 213137
# 1752 episode score is 797.47
# steps: 2457, all step: 215594
# 1761 episode score is 834.53
# steps: 2249, all step: 217843
# 1769 episode score is 875.28
# steps: 2077, all step: 219920
# 1779 episode score is 632.43
# steps: 2214, all step: 222134
# 1788 episode score is 795.93
# steps: 2100, all step: 224234
# 1796 episode score is 836.18
# steps: 2137, all step: 226371
# 1804 episode score is 859.94
# steps: 2326, all step: 228697
# 1812 episode score is 910.95
# steps: 2155, all step: 230852
# 1821 episode score is 759.60
# steps: 2166, all step: 233018
# 1830 episode score is 725.18
# steps: 2279, all step: 235297
# 1839 episode score is 811.91
# steps: 2302, all step: 237599
# 1848 episode score is 807.84
# steps: 2154, all step: 239753
# 1858 episode score is 680.15
# steps: 2055, all step: 241808
# 1866 episode score is 815.63
# steps: 2342, all step: 244150
# 1874 episode score is 934.61
# steps: 2067, all step: 246217
# 1882 episode score is 810.58
# steps: 2333, all step: 248550
# 1891 episode score is 822.10
# steps: 2122, all step: 250672
# 1899 episode score is 829.07
# steps: 2243, all step: 252915
# 1908 episode score is 810.69
# steps: 2065, all step: 254980
# 1916 episode score is 859.95
# steps: 2240, all step: 257220
# 1924 episode score is 910.73
# steps: 2373, all step: 259593
# 1933 episode score is 858.93
# steps: 2106, all step: 261699
# 1940 episode score is 1012.61
# steps: 2118, all step: 263817
# 1947 episode score is 999.21
# steps: 2137, all step: 265954
# 1953 episode score is 1165.68
# steps: 2195, all step: 268149
# 1959 episode score is 1158.71
# steps: 2151, all step: 270300
# 1965 episode score is 1166.90
# steps: 2349, all step: 272649
# 1972 episode score is 1095.85
# steps: 2143, all step: 274792
# 1979 episode score is 978.33
# steps: 2166, all step: 276958
# 1987 episode score is 840.75
# steps: 2208, all step: 279166
# 1995 episode score is 915.46
# steps: 2159, all step: 281325
# 2002 episode score is 980.17
# steps: 2107, all step: 283432
# 2009 episode score is 988.23
# steps: 2353, all step: 285785
# 2017 episode score is 958.30
# steps: 2164, all step: 287949
# 2024 episode score is 1007.94
# steps: 2158, all step: 290107
# 2031 episode score is 1028.61
# steps: 2379, all step: 292486
# 2040 episode score is 860.71
# steps: 2363, all step: 294849
# 2048 episode score is 971.16
# steps: 2058, all step: 296907
# 2056 episode score is 845.92
# steps: 2123, all step: 299030
# 2063 episode score is 992.77
# steps: 2208, all step: 301238
# 2071 episode score is 912.35
# steps: 2168, all step: 303406
# 2078 episode score is 998.21
# steps: 2402, all step: 305808
# 2085 episode score is 1128.13
# steps: 2228, all step: 308036
# 2092 episode score is 1038.30
# steps: 2065, all step: 310101
# 2100 episode score is 832.07
# steps: 2356, all step: 312457
# 2108 episode score is 970.36
# steps: 2195, all step: 314652
# 2116 episode score is 898.10
# steps: 2319, all step: 316971
# 2122 episode score is 1261.84
# steps: 2129, all step: 319100
# 2126 episode score is 1749.09
# steps: 2567, all step: 321667
# 2133 episode score is 1204.93
# steps: 2725, all step: 324392
# 2138 episode score is 1754.95
# steps: 2587, all step: 326979
# 2145 episode score is 1172.65
# steps: 2262, all step: 329241
# 2152 episode score is 1074.11
# steps: 2468, all step: 331709
# 2158 episode score is 1374.73
# steps: 2159, all step: 333868
# 2166 episode score is 873.14
# steps: 2206, all step: 336074
# 2173 episode score is 1036.00
# steps: 2078, all step: 338152
# 2180 episode score is 978.05
# steps: 2050, all step: 340202
# 2186 episode score is 1171.90
# steps: 2147, all step: 342349
# 2193 episode score is 1028.42
# steps: 2090, all step: 344439
# 2198 episode score is 1387.66
# steps: 2115, all step: 346554
# 2203 episode score is 1418.58
# steps: 2556, all step: 349110
# 2210 episode score is 1246.18
# steps: 2247, all step: 351357
# 2215 episode score is 1535.78
# steps: 2273, all step: 353630
# 2221 episode score is 1267.69
# steps: 2231, all step: 355861
# 2227 episode score is 1247.31
# steps: 2112, all step: 357973
# 2233 episode score is 1186.51
# steps: 2307, all step: 360280
# 2240 episode score is 1052.92
# steps: 2429, all step: 362709
# 2248 episode score is 1022.99
# steps: 2129, all step: 364838
# 2256 episode score is 897.27
# steps: 2269, all step: 367107
# 2264 episode score is 958.52
# steps: 2198, all step: 369305
# 2272 episode score is 923.78
# steps: 2059, all step: 371364
# 2280 episode score is 857.89
# steps: 2480, all step: 373844
# 2286 episode score is 1395.11
# steps: 2488, all step: 376332
# 2292 episode score is 1415.19
# steps: 2183, all step: 378515
# 2299 episode score is 1063.41
# steps: 2343, all step: 380858
# 2305 episode score is 1289.39
# steps: 2385, all step: 383243
# 2311 episode score is 1351.06
# steps: 2130, all step: 385373
# 2317 episode score is 1193.91
# steps: 2181, all step: 387554
# 2321 episode score is 1839.48
# steps: 2247, all step: 389801
# 2326 episode score is 1492.22
# steps: 2507, all step: 392308
# 2330 episode score is 2053.78
# steps: 2940, all step: 395248
# 2337 episode score is 1390.84
# steps: 2690, all step: 397938
# 2341 episode score is 2233.40
# steps: 2128, all step: 400066
# 2347 episode score is 1152.35
# steps: 2086, all step: 402152
# 2355 episode score is 879.29
# steps: 2235, all step: 404387
# 2362 episode score is 1092.59
# steps: 2344, all step: 406731
# 2369 episode score is 1124.21
# steps: 2150, all step: 408881
# 2375 episode score is 1207.20
# steps: 2387, all step: 411268
# 2383 episode score is 998.14
# steps: 2140, all step: 413408
# 2390 episode score is 1041.91
# steps: 2299, all step: 415707
# 2396 episode score is 1296.15
# steps: 2406, all step: 418113
# 2402 episode score is 1354.60
# steps: 2076, all step: 420189
# 2409 episode score is 999.91
# steps: 2335, all step: 422524
# 2416 episode score is 1103.07
# steps: 2071, all step: 424595
# 2422 episode score is 1188.19
# steps: 2193, all step: 426788
# 2428 episode score is 1256.27
# steps: 2121, all step: 428909
# 2435 episode score is 1025.46
# steps: 2094, all step: 431003
# 2443 episode score is 885.11
# steps: 2580, all step: 433583
# 2450 episode score is 1248.38
# steps: 2167, all step: 435750
# 2454 episode score is 1814.04
# steps: 2451, all step: 438201
# 2460 episode score is 1366.40
# steps: 2099, all step: 440300
# 2465 episode score is 1426.92
# steps: 2285, all step: 442585
# 2471 episode score is 1297.60
# steps: 2128, all step: 444713
# 2476 episode score is 1461.75
# steps: 2161, all step: 446874
# 2483 episode score is 1053.78
# steps: 2402, all step: 449276
# 2488 episode score is 1651.47
# steps: 2103, all step: 451379
# 2493 episode score is 1418.16
# steps: 2117, all step: 453496
# 2499 episode score is 1202.24
# steps: 2353, all step: 455849
# 2505 episode score is 1340.71
# steps: 2139, all step: 457988
# 2511 episode score is 1225.86
# steps: 2083, all step: 460071
# 2517 episode score is 1194.52
# steps: 2072, all step: 462143
# 2524 episode score is 1016.78
# steps: 2183, all step: 464326
# 2532 episode score is 939.12
# steps: 2142, all step: 466468
# 2537 episode score is 1455.34
# steps: 2659, all step: 469127
# 2542 episode score is 1752.05
# steps: 2254, all step: 471381
# 2545 episode score is 2442.28
# steps: 2698, all step: 474079
# 2551 episode score is 1510.02
# steps: 2647, all step: 476726
# 2554 episode score is 2769.84
# steps: 2300, all step: 479026
# 2558 episode score is 1935.58
# steps: 2319, all step: 481345
# 2562 episode score is 1898.89
# steps: 2756, all step: 484101
# 2567 episode score is 1869.83
# steps: 2093, all step: 486194
# 2572 episode score is 1421.74
# steps: 2337, all step: 488531
# 2579 episode score is 1133.40
# steps: 2142, all step: 490673
# 2583 episode score is 1818.98
# steps: 2562, all step: 493235
# 2589 episode score is 1431.77
# steps: 2347, all step: 495582
# 2595 episode score is 1333.31
# steps: 2125, all step: 497707
# 2600 episode score is 1444.95
# steps: 2300, all step: 500007
# 2605 episode score is 1546.06
# steps: 2567, all step: 502574
# 2611 episode score is 1450.02
# steps: 2986, all step: 505560
# 2618 episode score is 1420.41
# steps: 2297, all step: 507857
# 2623 episode score is 1577.98
# steps: 2395, all step: 510252
# 2629 episode score is 1372.21
# steps: 2258, all step: 512510
# 2633 episode score is 1920.53
# steps: 2308, all step: 514818
# 2638 episode score is 1571.74
# steps: 2793, all step: 517611
# 2642 episode score is 2295.65
# steps: 3000, all step: 520611
# 2645 episode score is 3169.55
# steps: 2580, all step: 523191
# 2650 episode score is 1758.75
# steps: 3000, all step: 526191
# 2653 episode score is 3157.49
# steps: 2891, all step: 529082
# 2657 episode score is 2351.81
# steps: 2146, all step: 531228
# 2660 episode score is 2345.73
# steps: 2050, all step: 533278
# 2663 episode score is 2352.35
# steps: 2252, all step: 535530
# 2670 episode score is 1092.54
# steps: 2340, all step: 537870
# 2675 episode score is 1574.67
# steps: 2063, all step: 539933
# 2681 episode score is 1173.19
# steps: 2162, all step: 542095
# 2688 episode score is 1038.80
# steps: 2133, all step: 544228
# 2691 episode score is 2326.50
# steps: 2271, all step: 546499
# 2696 episode score is 1516.96
# steps: 2155, all step: 548654
# 2700 episode score is 1773.58
# steps: 2368, all step: 551022
# 2703 episode score is 2550.18
# steps: 2276, all step: 553298
# 2707 episode score is 1831.70
# steps: 3000, all step: 556298
# 2710 episode score is 3177.97
# steps: 2275, all step: 558573
# 2713 episode score is 2427.09
# steps: 2084, all step: 560657
# 2716 episode score is 2290.54
# steps: 2124, all step: 562781
# 2719 episode score is 2301.91
# steps: 2647, all step: 565428
# 2723 episode score is 2239.11
# steps: 2682, all step: 568110
# 2729 episode score is 1530.83
# steps: 2187, all step: 570297
# 2733 episode score is 1859.37
# steps: 2734, all step: 573031
# 2737 episode score is 2330.42
# steps: 2660, all step: 575691
# 2740 episode score is 2969.63
# steps: 2204, all step: 577895
# 2744 episode score is 1883.33
# steps: 2066, all step: 579961
# 2748 episode score is 1781.27
# steps: 2413, all step: 582374
# 2753 episode score is 1630.74
# steps: 2710, all step: 585084
# 2759 episode score is 1541.63
# steps: 2267, all step: 587351
# 2763 episode score is 1923.44
# steps: 2115, all step: 589466
# 2768 episode score is 1447.55
# steps: 2056, all step: 591522
# 2773 episode score is 1407.80
# steps: 2278, all step: 593800
# 2777 episode score is 1944.16
# steps: 2627, all step: 596427
# 2781 episode score is 2183.78
# steps: 2180, all step: 598607
# 2785 episode score is 1835.55
# steps: 2057, all step: 600664
# 2789 episode score is 1710.06
# steps: 2091, all step: 602755
# 2794 episode score is 1440.83
# steps: 2185, all step: 604940
# 2800 episode score is 1250.68
# steps: 2319, all step: 607259
# 2805 episode score is 1608.12
# steps: 2380, all step: 609639
# 2809 episode score is 2054.27
# steps: 2117, all step: 611756
# 2816 episode score is 1034.45
# steps: 2714, all step: 614470
# 2822 episode score is 1552.12
# steps: 2197, all step: 616667
# 2825 episode score is 2463.87
# steps: 2154, all step: 618821
# 2830 episode score is 1486.27
# steps: 2485, all step: 621306
# 2835 episode score is 1699.18
# steps: 2168, all step: 623474
# 2840 episode score is 1487.05
# steps: 2453, all step: 625927
# 2845 episode score is 1697.43
# steps: 2315, all step: 628242
# 2853 episode score is 978.15
# steps: 2592, all step: 630834
# 2858 episode score is 1778.40
# steps: 2100, all step: 632934
# 2862 episode score is 1807.45
# steps: 2171, all step: 635105
# 2865 episode score is 2472.42
# steps: 2051, all step: 637156
# 2868 episode score is 2322.44
# steps: 2245, all step: 639401
# 2873 episode score is 1520.77
# steps: 2326, all step: 641727
# 2879 episode score is 1330.39
# steps: 2683, all step: 644410
# 2886 episode score is 1307.98
# steps: 3018, all step: 647428
# 2892 episode score is 1724.97
# steps: 2296, all step: 649724
# 2895 episode score is 2523.34
# steps: 2163, all step: 651887
# 2899 episode score is 1860.19
# steps: 2140, all step: 654027
# 2903 episode score is 1791.95
# steps: 2575, all step: 656602
# 2907 episode score is 2178.09
# steps: 2384, all step: 658986
# 2913 episode score is 1368.96
# steps: 2128, all step: 661114
# 2916 episode score is 2424.07
# steps: 2291, all step: 663405
# 2920 episode score is 1976.31
# steps: 2125, all step: 665530
# 2923 episode score is 2393.69
# steps: 2207, all step: 667737
# 2926 episode score is 2532.93
# steps: 2106, all step: 669843
# 2930 episode score is 1814.77
# steps: 3037, all step: 672880
# 2935 episode score is 2074.40
# steps: 2185, all step: 675065
# 2939 episode score is 1867.97
# steps: 2307, all step: 677372
# 2944 episode score is 1594.57
# steps: 2261, all step: 679633
# 2949 episode score is 1553.97
# steps: 2469, all step: 682102
# 2953 episode score is 2084.97
# steps: 2130, all step: 684232
# 2957 episode score is 1835.93
# steps: 2255, all step: 686487
# 2961 episode score is 1927.15
# steps: 2538, all step: 689025
# 2965 episode score is 2139.98
# steps: 2527, all step: 691552
# 2969 episode score is 2111.08
# steps: 2162, all step: 693714
# 2972 episode score is 2436.16
# steps: 2926, all step: 696640
# 2977 episode score is 1959.60
# steps: 2147, all step: 698787
# 2981 episode score is 1829.98
# steps: 2713, all step: 701500
# 2985 episode score is 2322.80
# steps: 2201, all step: 703701
# 2988 episode score is 2446.52
# steps: 2411, all step: 706112
# 2993 episode score is 1639.18
# steps: 2243, all step: 708355
# 2997 episode score is 1799.99
# steps: 2658, all step: 711013
# 3000 episode score is 2911.30
# steps: 2566, all step: 713579
# 3004 episode score is 2138.52
# steps: 2297, all step: 715876
# 3007 episode score is 2540.57
# steps: 2142, all step: 718018
# 3010 episode score is 2314.91
# steps: 2406, all step: 720424
# 3014 episode score is 2024.85
# steps: 2994, all step: 723418
# 3019 episode score is 1976.60
# steps: 3030, all step: 726448
# 3023 episode score is 2503.32
# steps: 2342, all step: 728790
# 3028 episode score is 1590.27
# steps: 2062, all step: 730852
# 3032 episode score is 1724.58
# steps: 2108, all step: 732960
# 3036 episode score is 1790.05
# steps: 2293, all step: 735253
# 3042 episode score is 1287.33
# steps: 2215, all step: 737468
# 3049 episode score is 1080.19
# steps: 2719, all step: 740187
# 3056 episode score is 1315.46
# steps: 2324, all step: 742511
# 3063 episode score is 1120.38
# steps: 2330, all step: 744841
# 3069 episode score is 1338.32
# steps: 2483, all step: 747324
# 3076 episode score is 1210.47
# steps: 2217, all step: 749541
# 3083 episode score is 1073.94
# steps: 2382, all step: 751923
# 3088 episode score is 1628.67
# steps: 2436, all step: 754359
# 3092 episode score is 2084.22
# steps: 2189, all step: 756548
# 3096 episode score is 1861.28
# steps: 2260, all step: 758808
# 3100 episode score is 1932.84
# steps: 2134, all step: 760942
# 3105 episode score is 1472.94
# steps: 2297, all step: 763239
# 3108 episode score is 2611.40
# steps: 2533, all step: 765772
# 3111 episode score is 2836.43
# steps: 2422, all step: 768194
# 3115 episode score is 2021.70
# steps: 2511, all step: 770705
# 3120 episode score is 1723.91
# steps: 2288, all step: 772993
# 3124 episode score is 1966.66
# steps: 2171, all step: 775164
# 3129 episode score is 1497.47
# steps: 2068, all step: 777232
# 3132 episode score is 2330.63
# steps: 2367, all step: 779599
# 3137 episode score is 1614.97
# steps: 2616, all step: 782215
# 3143 episode score is 1518.10
# steps: 2505, all step: 784720
# 3149 episode score is 1447.61
# steps: 2456, all step: 787176
# 3155 episode score is 1418.18
# steps: 2239, all step: 789415
# 3159 episode score is 1928.59
# steps: 2196, all step: 791611
# 3162 episode score is 2504.53
# steps: 2595, all step: 794206
# 3167 episode score is 1798.56
# steps: 2153, all step: 796359
# 3171 episode score is 1863.79
# steps: 2478, all step: 798837
# 3178 episode score is 1231.24
# steps: 2598, all step: 801435
# 3182 episode score is 2185.48
# steps: 2360, all step: 803795
# 3187 episode score is 1639.31
# steps: 2349, all step: 806144
# 3192 episode score is 1625.60
# steps: 2367, all step: 808511
# 3197 episode score is 1641.53
# steps: 2629, all step: 811140
# 3201 episode score is 2271.53
# steps: 2313, all step: 813453
# 3207 episode score is 1324.32
# steps: 2489, all step: 815942
# 3212 episode score is 1728.87
# steps: 2101, all step: 818043
# 3217 episode score is 1457.07
# steps: 2609, all step: 820652
# 3220 episode score is 2869.65
# steps: 2367, all step: 823019
# 3225 episode score is 1630.90
# steps: 2150, all step: 825169
# 3230 episode score is 1490.61
# steps: 2139, all step: 827308
# 3233 episode score is 2413.61
# steps: 2226, all step: 829534
# 3238 episode score is 1499.18
# steps: 2427, all step: 831961
# 3242 episode score is 2048.97
# steps: 2341, all step: 834302
# 3245 episode score is 2644.53
# steps: 2101, all step: 836403
# 3248 episode score is 2361.69
# steps: 2396, all step: 838799
# 3252 episode score is 2048.16
# steps: 2212, all step: 841011
# 3257 episode score is 1516.30
# steps: 2346, all step: 843357
# 3260 episode score is 2629.95
# steps: 2795, all step: 846152
# 3263 episode score is 3123.23
# steps: 2315, all step: 848467
# 3269 episode score is 1336.03
# steps: 2154, all step: 850621
# 3272 episode score is 2412.70
# steps: 3030, all step: 853651
# 3276 episode score is 2584.63
# steps: 2433, all step: 856084
# 3280 episode score is 2081.19
# steps: 2321, all step: 858405
# 3284 episode score is 1993.76
# steps: 2578, all step: 860983
# 3288 episode score is 2216.63
# steps: 2834, all step: 863817
# 3292 episode score is 2343.06
# steps: 2276, all step: 866093
# 3297 episode score is 1579.69
# steps: 2733, all step: 868826
# 3302 episode score is 1854.23
# steps: 2180, all step: 871006
# 3307 episode score is 1532.54
# steps: 2228, all step: 873234
# 3310 episode score is 2498.46
# steps: 2596, all step: 875830
# 3313 episode score is 2867.28
# steps: 2096, all step: 877926
# 3316 episode score is 2279.50
# steps: 2526, all step: 880452
# 3321 episode score is 1757.97
# steps: 2145, all step: 882597
# 3326 episode score is 1504.43
# steps: 2234, all step: 884831
# 3332 episode score is 1300.62
# steps: 2074, all step: 886905
# 3338 episode score is 1207.70
# steps: 2533, all step: 889438
# 3342 episode score is 2125.23
# steps: 2163, all step: 891601
# 3346 episode score is 1878.96
# steps: 2587, all step: 894188
# 3350 episode score is 2233.19
# steps: 2104, all step: 896292
# 3354 episode score is 1807.39
# steps: 2052, all step: 898344
# 3358 episode score is 1770.43
# steps: 2336, all step: 900680
# 3364 episode score is 1346.59
# steps: 2709, all step: 903389
# 3370 episode score is 1569.58
# steps: 2274, all step: 905663
# 3375 episode score is 1587.58
# steps: 2184, all step: 907847
# 3381 episode score is 1260.88
# steps: 2048, all step: 909895
# 3384 episode score is 2363.26
# steps: 2106, all step: 912001
# 3389 episode score is 1487.51
# steps: 2198, all step: 914199
# 3395 episode score is 1268.95
# steps: 2323, all step: 916522
# 3401 episode score is 1348.46
# steps: 2895, all step: 919417
# 3406 episode score is 1927.28
# steps: 2436, all step: 921853
# 3411 episode score is 1719.05
# steps: 2539, all step: 924392
# 3415 episode score is 2191.57
# steps: 2602, all step: 926994
# 3419 episode score is 2268.76
# steps: 2085, all step: 929079
# 3422 episode score is 2367.21
# steps: 2582, all step: 931661
# 3427 episode score is 1783.96
# steps: 2189, all step: 933850
# 3432 episode score is 1527.77
# steps: 2311, all step: 936161
# 3435 episode score is 2616.97
# steps: 2124, all step: 938285
# 3439 episode score is 1812.22
# steps: 2652, all step: 940937
# 3443 episode score is 2239.95
# steps: 2271, all step: 943208
# 3446 episode score is 2589.04
# steps: 2103, all step: 945311
# 3450 episode score is 1768.72
# steps: 2558, all step: 947869
# 3454 episode score is 2178.67
# steps: 2339, all step: 950208
# 3458 episode score is 1984.93
# steps: 2422, all step: 952630
# 3464 episode score is 1374.67
# steps: 2205, all step: 954835
# 3470 episode score is 1301.58
# steps: 2272, all step: 957107
# 3475 episode score is 1552.59
# steps: 2190, all step: 959297
# 3479 episode score is 1911.96
# steps: 2217, all step: 961514
# 3482 episode score is 2517.00
# steps: 2335, all step: 963849
# 3486 episode score is 2024.28
# steps: 2453, all step: 966302
# 3489 episode score is 2771.36
# steps: 2503, all step: 968805
# 3492 episode score is 2825.70
# steps: 2813, all step: 971618
# 3497 episode score is 1919.14
# steps: 2407, all step: 974025
# 3502 episode score is 1664.74
# steps: 2220, all step: 976245
# 3508 episode score is 1300.50
# steps: 2619, all step: 978864
# 3512 episode score is 2261.13
# steps: 2145, all step: 981009
# 3518 episode score is 1261.29
# steps: 2366, all step: 983375
# 3523 episode score is 1611.65
# steps: 2428, all step: 985803
# 3527 episode score is 2071.20
# steps: 2431, all step: 988234
# 3533 episode score is 1392.34
# steps: 2534, all step: 990768
# 3537 episode score is 2133.70
# steps: 2302, all step: 993070
# 3544 episode score is 1141.69
# steps: 2250, all step: 995320
# 3550 episode score is 1309.41
# steps: 2314, all step: 997634
# 3556 episode score is 1337.15
# steps: 2279, all step: 999913
# 3562 episode score is 1334.10
# steps: 2279, all step: 1002192
# 3567 episode score is 1576.21
# steps: 2223, all step: 1004415
# 3572 episode score is 1539.05
# steps: 2159, all step: 1006574
# 3576 episode score is 1883.03
# steps: 2416, all step: 1008990
# 3583 episode score is 1193.41
# steps: 2469, all step: 1011459
# 3587 episode score is 2117.11
# steps: 2423, all step: 1013882
# 3592 episode score is 1670.43
# steps: 2271, all step: 1016153
# 3598 episode score is 1317.36
# steps: 2618, all step: 1018771
# 3602 episode score is 2256.14
# steps: 2938, all step: 1021709
# 3608 episode score is 1695.52
# steps: 2076, all step: 1023785
# 3611 episode score is 2348.95
# steps: 2375, all step: 1026160
# 3616 episode score is 1619.70
# steps: 2999, all step: 1029159
# 3620 episode score is 2538.43
# steps: 2279, all step: 1031438
# 3625 episode score is 1598.85
# steps: 2260, all step: 1033698
# 3631 episode score is 1318.28
# steps: 2059, all step: 1035757
# 3636 episode score is 1440.22
# steps: 2865, all step: 1038622
# 3641 episode score is 1962.30
# steps: 2185, all step: 1040807
# 3648 episode score is 1081.32
# steps: 2160, all step: 1042967
# 3655 episode score is 1067.27
# steps: 2198, all step: 1045165
# 3660 episode score is 1527.40
# steps: 2410, all step: 1047575
# 3665 episode score is 1670.58
# steps: 2399, all step: 1049974
# 3670 episode score is 1670.94
# steps: 2147, all step: 1052121
# 3674 episode score is 1836.71
# steps: 2521, all step: 1054642
# 3678 episode score is 2189.49
# steps: 2383, all step: 1057025
# 3684 episode score is 1389.74
# steps: 2412, all step: 1059437
# 3689 episode score is 1675.39
# steps: 2369, all step: 1061806
# 3695 episode score is 1373.05
# steps: 2219, all step: 1064025
# 3700 episode score is 1544.91
# steps: 2356, all step: 1066381
# 3705 episode score is 1640.94
# steps: 2338, all step: 1068719
# 3710 episode score is 1633.81
# steps: 2188, all step: 1070907
# 3714 episode score is 1894.04
# steps: 2097, all step: 1073004
# 3718 episode score is 1822.41
# steps: 2225, all step: 1075229
# 3724 episode score is 1295.93
# steps: 2138, all step: 1077367
# 3728 episode score is 1847.09
# steps: 2545, all step: 1079912
# 3734 episode score is 1474.33
# steps: 2409, all step: 1082321
# 3739 episode score is 1683.09
# steps: 2378, all step: 1084699
# 3746 episode score is 1178.10
# steps: 2234, all step: 1086933
# 3751 episode score is 1559.31
# steps: 2722, all step: 1089655
# 3757 episode score is 1586.94
# steps: 2178, all step: 1091833
# 3762 episode score is 1518.70
# steps: 2541, all step: 1094374
# 3768 episode score is 1485.97
# steps: 2225, all step: 1096599
# 3773 episode score is 1546.49
# steps: 2202, all step: 1098801
# 3778 episode score is 1531.61
# steps: 2345, all step: 1101146
# 3783 episode score is 1605.20
# steps: 2781, all step: 1103927
# 3788 episode score is 1926.24
# steps: 2146, all step: 1106073
# 3793 episode score is 1486.62
# steps: 2311, all step: 1108384
# 3798 episode score is 1617.11
# steps: 2202, all step: 1110586
# 3802 episode score is 1903.85
# steps: 2348, all step: 1112934
# 3807 episode score is 1653.09
# steps: 2071, all step: 1115005
# 3813 episode score is 1210.36
# steps: 2087, all step: 1117092
# 3816 episode score is 2365.74
# steps: 2590, all step: 1119682
# 3820 episode score is 2242.01
# steps: 2119, all step: 1121801
# 3824 episode score is 1846.44
# steps: 2455, all step: 1124256
# 3830 episode score is 1440.15
# steps: 2099, all step: 1126355
# 3835 episode score is 1476.79
# steps: 2225, all step: 1128580
# 3839 episode score is 1941.21
# steps: 2326, all step: 1130906
# 3845 episode score is 1362.25
# steps: 2260, all step: 1133166
# 3850 episode score is 1576.14
# steps: 2186, all step: 1135352
# 3854 episode score is 1895.51
# steps: 2283, all step: 1137635
# 3860 episode score is 1345.04
# steps: 2212, all step: 1139847
# 3866 episode score is 1290.70
# steps: 2184, all step: 1142031
# 3870 episode score is 1913.37
# steps: 2083, all step: 1144114
# 3875 episode score is 1461.06
# steps: 2164, all step: 1146278
# 3880 episode score is 1515.24
# steps: 2148, all step: 1148426
# 3885 episode score is 1518.65
# steps: 2125, all step: 1150551
# 3891 episode score is 1252.49
# steps: 2229, all step: 1152780
# 3896 episode score is 1565.69
# steps: 2136, all step: 1154916
# 3900 episode score is 1865.21
# steps: 2694, all step: 1157610
# 3906 episode score is 1584.47
# steps: 2090, all step: 1159700
# 3911 episode score is 1482.84
# steps: 2078, all step: 1161778
# 3915 episode score is 1817.14
# steps: 2261, all step: 1164039
# 3922 episode score is 1140.71
# steps: 2370, all step: 1166409
# 3928 episode score is 1393.52
# steps: 2546, all step: 1168955
# 3934 episode score is 1485.93
# steps: 2280, all step: 1171235
# 3939 episode score is 1592.83
# steps: 2471, all step: 1173706
# 3943 episode score is 2151.10
# steps: 2085, all step: 1175791
# 3948 episode score is 1470.07
# steps: 2261, all step: 1178052
# 3951 episode score is 2581.81
# steps: 2200, all step: 1180252
# 3954 episode score is 2514.14
# steps: 2634, all step: 1182886
# 3959 episode score is 1812.06
# steps: 2298, all step: 1185184
# 3964 episode score is 1631.90
# steps: 2489, all step: 1187673
# 3968 episode score is 2196.58
# steps: 2245, all step: 1189918
# 3973 episode score is 1587.45
# steps: 2549, all step: 1192467
# 3979 episode score is 1516.31
# steps: 2289, all step: 1194756
# 3986 episode score is 1156.53
# steps: 2277, all step: 1197033
# 3992 episode score is 1352.33
# steps: 2287, all step: 1199320
# 3997 episode score is 1619.66
# steps: 2603, all step: 1201923
# 4003 episode score is 1540.61
# steps: 2122, all step: 1204045
# 4009 episode score is 1240.98
# steps: 2448, all step: 1206493
# 4014 episode score is 1723.44
# steps: 2193, all step: 1208686
# 4019 episode score is 1558.08
# steps: 2224, all step: 1210910
# 4024 episode score is 1582.46
# steps: 2148, all step: 1213058
# 4029 episode score is 1520.53
# steps: 2313, all step: 1215371
# 4033 episode score is 2066.76
# steps: 2248, all step: 1217619
# 4040 episode score is 1135.63
# steps: 2101, all step: 1219720
# 4045 episode score is 1502.08
# steps: 2368, all step: 1222088
# 4049 episode score is 2073.68
# steps: 2150, all step: 1224238
# 4055 episode score is 1271.30
# steps: 2420, all step: 1226658
# 4062 episode score is 1241.95
# steps: 2309, all step: 1228967
# 4069 episode score is 1176.61
# steps: 2263, all step: 1231230
# 4074 episode score is 1602.49
# steps: 2116, all step: 1233346
# 4079 episode score is 1501.45
# steps: 2191, all step: 1235537
# 4083 episode score is 1921.83
# steps: 2489, all step: 1238026
# 4087 episode score is 2224.53
# steps: 2437, all step: 1240463
# 4093 episode score is 1444.95
# steps: 2339, all step: 1242802
# 4096 episode score is 2732.13
# steps: 2162, all step: 1244964
# 4101 episode score is 1544.51
# steps: 2428, all step: 1247392
# 4106 episode score is 1727.72
# steps: 2243, all step: 1249635
# 4110 episode score is 1954.78
# steps: 2859, all step: 1252494
# 4114 episode score is 2441.42
# steps: 2299, all step: 1254793
# 4118 episode score is 1989.71
# steps: 2729, all step: 1257522
# 4124 episode score is 1611.30
# steps: 2073, all step: 1259595
# 4127 episode score is 2445.16
# steps: 2607, all step: 1262202
# 4132 episode score is 1851.41
# steps: 2492, all step: 1264694
# 4138 episode score is 1472.04
# steps: 2284, all step: 1266978
# 4143 episode score is 1614.13
# steps: 2423, all step: 1269401
# 4147 episode score is 2148.55
# steps: 2067, all step: 1271468
# 4150 episode score is 2454.65
# steps: 2676, all step: 1274144
# 4153 episode score is 3054.17
# steps: 2176, all step: 1276320
# 4156 episode score is 2554.70
# steps: 2763, all step: 1279083
# 4161 episode score is 1934.19
# steps: 2899, all step: 1281982
# 4165 episode score is 2533.01
# steps: 2055, all step: 1284037
# 4169 episode score is 1821.54
# steps: 2253, all step: 1286290
# 4172 episode score is 2634.09
# steps: 2564, all step: 1288854
# 4176 episode score is 2236.85
# steps: 2184, all step: 1291038
# 4179 episode score is 2503.02
# steps: 2120, all step: 1293158
# 4183 episode score is 1885.76
# steps: 3040, all step: 1296198
# 4187 episode score is 2638.63
# steps: 2664, all step: 1298862
# 4191 episode score is 2337.63
# steps: 2973, all step: 1301835
# 4194 episode score is 3406.69
# steps: 2341, all step: 1304176
# 4197 episode score is 2636.12
# steps: 2375, all step: 1306551
# 4200 episode score is 2724.78
# steps: 2406, all step: 1308957
# 4203 episode score is 2742.33
# steps: 2955, all step: 1311912
# 4206 episode score is 3380.41
# steps: 2257, all step: 1314169
# 4210 episode score is 1961.88
# steps: 2127, all step: 1316296
# 4213 episode score is 2515.52
# steps: 2064, all step: 1318360
# 4216 episode score is 2371.97
# steps: 3000, all step: 1321360
# 4219 episode score is 3363.71
# steps: 2527, all step: 1323887
# 4222 episode score is 2908.83
# steps: 2538, all step: 1326425
# 4225 episode score is 2876.59
# steps: 2627, all step: 1329052
# 4229 episode score is 2192.49
# steps: 2247, all step: 1331299
# 4232 episode score is 2547.03
# steps: 2116, all step: 1333415
# 4235 episode score is 2513.68
# steps: 2281, all step: 1335696
# 4238 episode score is 2648.39
# steps: 2867, all step: 1338563
# 4242 episode score is 2485.38
# steps: 2688, all step: 1341251
# 4246 episode score is 2352.46
# steps: 2333, all step: 1343584
# 4249 episode score is 2666.17
# steps: 2512, all step: 1346096
# 4252 episode score is 2957.50
# steps: 2700, all step: 1348796
# 4256 episode score is 2369.88
# steps: 2170, all step: 1350966
# 4259 episode score is 2515.64
# steps: 2467, all step: 1353433
# 4263 episode score is 2195.08
# steps: 2103, all step: 1355536
# 4268 episode score is 1487.98
# steps: 2056, all step: 1357592
# 4272 episode score is 1801.33
# steps: 2130, all step: 1359722
# 4275 episode score is 2489.50
# steps: 2206, all step: 1361928
# 4278 episode score is 2566.07
# steps: 3000, all step: 1364928
# 4281 episode score is 3420.61
# steps: 2452, all step: 1367380
# 4285 episode score is 2169.83
# steps: 2282, all step: 1369662
# 4288 episode score is 2667.18
# steps: 2463, all step: 1372125
# 4292 episode score is 2187.27
# steps: 2221, all step: 1374346
# 4297 episode score is 1575.72
# steps: 2168, all step: 1376514
# 4300 episode score is 2536.77
# steps: 2386, all step: 1378900
# 4304 episode score is 2112.91
# steps: 2366, all step: 1381266
# 4308 episode score is 2120.08
# steps: 2486, all step: 1383752
# 4312 episode score is 2166.23
# steps: 2137, all step: 1385889
# 4315 episode score is 2511.25
# steps: 2205, all step: 1388094
# 4318 episode score is 2604.46
# steps: 2396, all step: 1390490
# 4321 episode score is 2744.05
# steps: 2196, all step: 1392686
# 4326 episode score is 1568.65
# steps: 2234, all step: 1394920
# 4330 episode score is 1973.67
# steps: 2853, all step: 1397773
# 4334 episode score is 2501.65
# steps: 2752, all step: 1400525
# 4337 episode score is 3204.74
# steps: 2187, all step: 1402712
# 4342 episode score is 1531.15
# steps: 2206, all step: 1404918
# 4345 episode score is 2560.47
# steps: 2474, all step: 1407392
# 4348 episode score is 2852.19
# steps: 2658, all step: 1410050
# 4353 episode score is 1870.74
# steps: 2351, all step: 1412401
# 4359 episode score is 1355.26
# steps: 2350, all step: 1414751
# 4362 episode score is 2722.71
# steps: 2121, all step: 1416872
# 4366 episode score is 1852.26
# steps: 2071, all step: 1418943
# 4369 episode score is 2465.91
# steps: 2497, all step: 1421440
# 4373 episode score is 2195.74
# steps: 2436, all step: 1423876
# 4376 episode score is 2837.26
# steps: 2264, all step: 1426140
# 4381 episode score is 1603.62
# steps: 2931, all step: 1429071
# 4387 episode score is 1707.35
# steps: 3012, all step: 1432083
# 4393 episode score is 1767.91
# steps: 2579, all step: 1434662
# 4398 episode score is 1830.85
# steps: 2086, all step: 1436748
# 4402 episode score is 1865.04
# steps: 2290, all step: 1439038
# 4407 episode score is 1626.41
# steps: 2151, all step: 1441189
# 4412 episode score is 1537.50
# steps: 2669, all step: 1443858
# 4419 episode score is 1349.11
# steps: 2322, all step: 1446180
# 4423 episode score is 2086.26
# steps: 2475, all step: 1448655
# 4430 episode score is 1254.43
# steps: 2493, all step: 1451148
# 4434 episode score is 2233.73
# steps: 2278, all step: 1453426
# 4439 episode score is 1637.41
# steps: 2337, all step: 1455763
# 4442 episode score is 2720.08
# steps: 2086, all step: 1457849
# 4447 episode score is 1500.81
# steps: 2888, all step: 1460737
# 4453 episode score is 1715.21
# steps: 2252, all step: 1462989
# 4459 episode score is 1334.65
# steps: 2356, all step: 1465345
# 4465 episode score is 1384.01
# steps: 2266, all step: 1467611
# 4468 episode score is 2601.99
# steps: 2452, all step: 1470063
# 4472 episode score is 2217.98
# steps: 2278, all step: 1472341
# 4477 episode score is 1637.43
# steps: 2106, all step: 1474447
# 4483 episode score is 1251.44
# steps: 2261, all step: 1476708
# 4486 episode score is 2652.87
# steps: 2069, all step: 1478777
# 4490 episode score is 1871.59
# steps: 2319, all step: 1481096
# 4495 episode score is 1685.28
# steps: 2334, all step: 1483430
# 4499 episode score is 2096.62
# steps: 2098, all step: 1485528
# 4503 episode score is 1884.24
# steps: 2227, all step: 1487755
# 4508 episode score is 1611.29
# steps: 2210, all step: 1489965
# 4512 episode score is 1996.21
# steps: 2178, all step: 1492143
# 4517 episode score is 1554.66
# steps: 2501, all step: 1494644
# 4522 episode score is 1815.56
# steps: 2196, all step: 1496840
# 4526 episode score is 1963.59
# steps: 2364, all step: 1499204
# 4529 episode score is 2803.49
# steps: 2888, all step: 1502092
# 4534 episode score is 2074.51
# steps: 2738, all step: 1504830
# 4538 episode score is 2435.55
# steps: 2921, all step: 1507751
# 4543 episode score is 2092.63
# steps: 2168, all step: 1509919
# 4547 episode score is 1961.47
# steps: 2554, all step: 1512473
# 4551 episode score is 2284.92
# steps: 2057, all step: 1514530
# 4554 episode score is 2442.19
# steps: 2321, all step: 1516851
# 4558 episode score is 2049.22
# steps: 2842, all step: 1519693
# 4562 episode score is 2476.52
# steps: 2526, all step: 1522219
# 4565 episode score is 2975.22
# steps: 2290, all step: 1524509
# 4569 episode score is 2050.96
# steps: 2626, all step: 1527135
# 4572 episode score is 3136.56
# steps: 2376, all step: 1529511
# 4577 episode score is 1720.27
# steps: 2367, all step: 1531878
# 4582 episode score is 1709.24
# steps: 2299, all step: 1534177
# 4586 episode score is 2083.05
# steps: 2597, all step: 1536774
# 4590 episode score is 2366.96
# steps: 2684, all step: 1539458
# 4594 episode score is 2448.22
# steps: 2311, all step: 1541769
# 4597 episode score is 2793.15
# steps: 2378, all step: 1544147
# 4600 episode score is 2843.83
# steps: 2195, all step: 1546342
# 4603 episode score is 2646.96
# steps: 2206, all step: 1548548
# 4607 episode score is 2025.19
# steps: 2714, all step: 1551262
# 4611 episode score is 2443.11
# steps: 2399, all step: 1553661
# 4615 episode score is 2173.39
# steps: 2361, all step: 1556022
# 4618 episode score is 2768.75
# steps: 2140, all step: 1558162
# 4622 episode score is 1910.92
# steps: 2581, all step: 1560743
# 4625 episode score is 3060.66
# steps: 2910, all step: 1563653
# 4629 episode score is 2611.86
# steps: 2278, all step: 1565931
# 4632 episode score is 2678.57
# steps: 2173, all step: 1568104
# 4635 episode score is 2556.08
# steps: 2489, all step: 1570593
# 4638 episode score is 2928.04
# steps: 2575, all step: 1573168
# 4641 episode score is 3092.73
# steps: 2266, all step: 1575434
# 4644 episode score is 2743.29
# steps: 2279, all step: 1577713
# 4647 episode score is 2733.96
# steps: 2168, all step: 1579881
# 4650 episode score is 2605.56
# steps: 2700, all step: 1582581
# 4654 episode score is 2403.48
# steps: 2954, all step: 1585535
# 4658 episode score is 2617.48
# steps: 2209, all step: 1587744
# 4662 episode score is 1985.02
# steps: 2870, all step: 1590614
# 4666 episode score is 2571.18
# steps: 2710, all step: 1593324
# 4670 episode score is 2415.24
# steps: 2540, all step: 1595864
# 4673 episode score is 3065.24
# steps: 2201, all step: 1598065
# 4677 episode score is 1994.98
# steps: 2095, all step: 1600160
# 4681 episode score is 1915.54
# steps: 2113, all step: 1602273
# 4685 episode score is 1934.53
# steps: 2519, all step: 1604792
# 4689 episode score is 2299.63
# steps: 2599, all step: 1607391
# 4693 episode score is 2358.46
# steps: 2231, all step: 1609622
# 4697 episode score is 2033.39
# steps: 2274, all step: 1611896
# 4701 episode score is 2096.64
# steps: 2366, all step: 1614262
# 4705 episode score is 2117.70
# steps: 2708, all step: 1616970
# 4711 episode score is 1640.23
# steps: 2416, all step: 1619386
# 4716 episode score is 1743.34
# steps: 2507, all step: 1621893
# 4719 episode score is 2989.05
# steps: 2140, all step: 1624033
# 4723 episode score is 1951.83
# steps: 2412, all step: 1626445
# 4727 episode score is 2169.55
# steps: 2171, all step: 1628616
# 4730 episode score is 2550.21
# steps: 2532, all step: 1631148
# 4733 episode score is 3007.19
# steps: 2488, all step: 1633636
# 4736 episode score is 2998.79
# steps: 2854, all step: 1636490
# 4739 episode score is 3389.99
# steps: 2318, all step: 1638808
# 4742 episode score is 2755.38
# steps: 2206, all step: 1641014
# 4747 episode score is 1626.17
# steps: 2083, all step: 1643097
# 4751 episode score is 1893.83
# steps: 2668, all step: 1645765
# 4754 episode score is 3240.64
# steps: 2322, all step: 1648087
# 4759 episode score is 1689.79
# steps: 2217, all step: 1650304
# 4762 episode score is 2720.95
# steps: 2528, all step: 1652832
# 4765 episode score is 3034.31
# steps: 2334, all step: 1655166
# 4768 episode score is 2798.59
# steps: 2589, all step: 1657755
# 4772 episode score is 2353.57
# steps: 2557, all step: 1660312
# 4775 episode score is 3093.54
# steps: 2567, all step: 1662879
# 4780 episode score is 1865.00
# steps: 2690, all step: 1665569
# 4783 episode score is 3224.91
# steps: 2538, all step: 1668107
# 4787 episode score is 2308.97
# steps: 2354, all step: 1670461
# 4790 episode score is 2767.72
# steps: 2118, all step: 1672579
# 4794 episode score is 1905.38
# steps: 2423, all step: 1675002
# 4798 episode score is 2206.84
# steps: 2862, all step: 1677864
# 4802 episode score is 2572.24
# steps: 2269, all step: 1680133
# 4806 episode score is 2035.87
# steps: 2861, all step: 1682994
# 4810 episode score is 2522.23
# steps: 2584, all step: 1685578
# 4814 episode score is 2368.29
# steps: 2990, all step: 1688568
# 4818 episode score is 2733.81
# steps: 2636, all step: 1691204
# 4821 episode score is 3118.11
# steps: 2136, all step: 1693340
# 4825 episode score is 1936.75
# steps: 2921, all step: 1696261
# 4829 episode score is 2665.83
# steps: 2408, all step: 1698669
# 4833 episode score is 2202.01
# steps: 2888, all step: 1701557
# 4837 episode score is 2617.06
# steps: 2380, all step: 1703937
# 4840 episode score is 2848.81
# steps: 2324, all step: 1706261
# 4843 episode score is 2721.58
# steps: 2591, all step: 1708852
# 4847 episode score is 2339.31
# steps: 2636, all step: 1711488
# 4850 episode score is 3102.09
# steps: 2974, all step: 1714462
# 4854 episode score is 2568.28
# steps: 2475, all step: 1716937
# 4857 episode score is 2888.05
# steps: 2704, all step: 1719641
# 4861 episode score is 2387.97
# steps: 3000, all step: 1722641
# 4864 episode score is 3426.70
# steps: 2772, all step: 1725413
# 4868 episode score is 2458.02
# steps: 2392, all step: 1727805
# 4871 episode score is 2845.54
# steps: 2986, all step: 1730791
# 4875 episode score is 2628.98
# steps: 2314, all step: 1733105
# 4878 episode score is 2755.42
# steps: 2371, all step: 1735476
# 4881 episode score is 2802.62
# steps: 3021, all step: 1738497
# 4885 episode score is 2660.14
# steps: 2466, all step: 1740963
# 4890 episode score is 1785.26
# steps: 2059, all step: 1743022
# 4894 episode score is 1865.74
# steps: 2128, all step: 1745150
# 4899 episode score is 1549.01
# steps: 2227, all step: 1747377
# 4902 episode score is 2631.46
# steps: 2463, all step: 1749840
# 4905 episode score is 2947.51
# steps: 2442, all step: 1752282
# 4909 episode score is 2172.74
# steps: 2444, all step: 1754726
# 4914 episode score is 1783.13
# steps: 2115, all step: 1756841
# 4918 episode score is 1898.13
# steps: 2714, all step: 1759555
# 4921 episode score is 3222.99
# steps: 2824, all step: 1762379
# 4926 episode score is 1989.79
# steps: 2400, all step: 1764779
# 4931 episode score is 1741.96
# steps: 2294, all step: 1767073
# 4935 episode score is 2075.14
# steps: 2799, all step: 1769872
# 4940 episode score is 2021.31
# steps: 2120, all step: 1771992
# 4944 episode score is 1930.50
# steps: 2654, all step: 1774646
# 4948 episode score is 2397.24
# steps: 2863, all step: 1777509
# 4951 episode score is 3353.27
# steps: 2643, all step: 1780152
# 4955 episode score is 2394.11
# steps: 2385, all step: 1782537
# 4959 episode score is 2166.42
# steps: 2256, all step: 1784793
# 4963 episode score is 2040.80
# steps: 2264, all step: 1787057
# 4968 episode score is 1628.66
# steps: 2489, all step: 1789546
# 4971 episode score is 2984.27
# steps: 2633, all step: 1792179
# 4976 episode score is 1859.15
# steps: 2220, all step: 1794399
# 4979 episode score is 2634.43
# steps: 2662, all step: 1797061
# 4982 episode score is 3118.88
# steps: 2788, all step: 1799849
# 4985 episode score is 3258.69
# steps: 2674, all step: 1802523
# 4988 episode score is 3107.49
# steps: 2624, all step: 1805147
# 4991 episode score is 3016.62
# steps: 2897, all step: 1808044
# 4994 episode score is 3276.67
# steps: 2663, all step: 1810707
# 4997 episode score is 3032.17
# steps: 3000, all step: 1813707
# 5000 episode score is 3357.36
# steps: 2265, all step: 1815972
# 5003 episode score is 2582.07
# steps: 3000, all step: 1818972
# 5006 episode score is 3341.60
# steps: 2278, all step: 1821250
# 5010 episode score is 1983.20
# steps: 3019, all step: 1824269
# 5015 episode score is 2093.59
# steps: 2379, all step: 1826648
# 5019 episode score is 2057.37
# steps: 2105, all step: 1828753
# 5023 episode score is 1839.27
# steps: 2666, all step: 1831419
# 5028 episode score is 1898.93
# steps: 2171, all step: 1833590
# 5032 episode score is 1900.85
# steps: 2103, all step: 1835693
# 5035 episode score is 2487.72
# steps: 2321, all step: 1838014
# 5040 episode score is 1646.64
# steps: 2738, all step: 1840752
# 5043 episode score is 3184.96
# steps: 2281, all step: 1843033
# 5048 episode score is 1648.19
# steps: 2101, all step: 1845134
# 5053 episode score is 1472.79
# steps: 3039, all step: 1848173
# 5058 episode score is 2226.54
# steps: 3018, all step: 1851191
# 5063 episode score is 2122.16
# steps: 2092, all step: 1853283
# 5067 episode score is 1875.47
# steps: 2599, all step: 1855882
# 5071 episode score is 2322.60
# steps: 2205, all step: 1858087
# 5076 episode score is 1598.78
# steps: 2377, all step: 1860464
# 5082 episode score is 1433.64
# steps: 2484, all step: 1862948
# 5087 episode score is 1800.03
# steps: 2323, all step: 1865271
# 5091 episode score is 2122.32
# steps: 2561, all step: 1867832
# 5095 episode score is 2310.12
# steps: 2207, all step: 1870039
# 5098 episode score is 2639.83
# steps: 2188, all step: 1872227
# 5102 episode score is 1963.43
# steps: 2097, all step: 1874324
# 5107 episode score is 1485.53
# steps: 2347, all step: 1876671
# 5112 episode score is 1723.75
# steps: 2380, all step: 1879051
# 5116 episode score is 2154.77
# steps: 2098, all step: 1881149
# 5121 episode score is 1504.30
# steps: 2048, all step: 1883197
# 5127 episode score is 1227.89
# steps: 2744, all step: 1885941
# 5131 episode score is 2434.26
# steps: 2658, all step: 1888599
# 5135 episode score is 2383.81
# steps: 2633, all step: 1891232
# 5140 episode score is 1911.09
# steps: 2180, all step: 1893412
# 5146 episode score is 1316.68
# steps: 2205, all step: 1895617
# 5149 episode score is 2666.65
# steps: 2235, all step: 1897852
# 5152 episode score is 2686.52
# steps: 2781, all step: 1900633
# 5156 episode score is 2515.76
# steps: 2443, all step: 1903076
# 5159 episode score is 2939.54
# steps: 2546, all step: 1905622
# 5164 episode score is 1851.82
# steps: 2422, all step: 1908044
# 5168 episode score is 2192.81
# steps: 2603, all step: 1910647
# 5171 episode score is 3128.91
# steps: 2431, all step: 1913078
# 5175 episode score is 2204.69
# steps: 2086, all step: 1915164
# 5178 episode score is 2496.69
# steps: 2254, all step: 1917418
# 5182 episode score is 2058.09
# steps: 2372, all step: 1919790
# 5185 episode score is 2859.93
# steps: 2688, all step: 1922478
# 5188 episode score is 3196.04
# steps: 2527, all step: 1925005
# 5192 episode score is 2310.45
# steps: 2562, all step: 1927567
# 5195 episode score is 3015.89
# steps: 2626, all step: 1930193
# 5198 episode score is 3105.76
# steps: 2331, all step: 1932524
# 5202 episode score is 2113.38
# steps: 2838, all step: 1935362
# 5206 episode score is 2548.92
# steps: 2235, all step: 1937597
# 5211 episode score is 1612.69
# steps: 2742, all step: 1940339
# 5214 episode score is 3217.36
# steps: 2282, all step: 1942621
# 5218 episode score is 2094.75
# steps: 2672, all step: 1945293
# 5221 episode score is 3204.19
# steps: 2484, all step: 1947777
# 5224 episode score is 2987.44
# steps: 2150, all step: 1949927
# 5227 episode score is 2551.04
# steps: 2890, all step: 1952817
# 5230 episode score is 3455.96
# steps: 2621, all step: 1955438
# 5233 episode score is 3184.44
# steps: 2649, all step: 1958087
# 5236 episode score is 3081.85
# steps: 2660, all step: 1960747
# 5240 episode score is 2325.29
# steps: 2493, all step: 1963240
# 5244 episode score is 2216.04
# steps: 2629, all step: 1965869
# 5247 episode score is 3140.71
# steps: 2416, all step: 1968285
# 5250 episode score is 2887.16
# steps: 2388, all step: 1970673
# 5254 episode score is 2117.83
# steps: 3017, all step: 1973690
# 5258 episode score is 2721.82
# steps: 3000, all step: 1976690
# 5261 episode score is 3493.91
# steps: 2953, all step: 1979643
# 5264 episode score is 3479.17
# steps: 3000, all step: 1982643
# 5267 episode score is 3485.07
# steps: 3038, all step: 1985681
# 5271 episode score is 2702.91
# steps: 2593, all step: 1988274
# 5275 episode score is 2274.86
# steps: 2601, all step: 1990875
# 5279 episode score is 2338.91
# steps: 2848, all step: 1993723
# 5282 episode score is 3377.82
# steps: 2882, all step: 1996605
# 5286 episode score is 2559.28
# steps: 3000, all step: 1999605
# 5289 episode score is 3515.11
# steps: 2513, all step: 2002118
# 5292 episode score is 3028.53
# steps: 2202, all step: 2004320
# 5295 episode score is 2586.86
# steps: 2483, all step: 2006803
# 5298 episode score is 2980.97
# steps: 2250, all step: 2009053
# 5302 episode score is 2040.92
# steps: 2640, all step: 2011693
# 5305 episode score is 3191.89
# steps: 2353, all step: 2014046
# 5310 episode score is 1723.58
# steps: 2143, all step: 2016189
# 5313 episode score is 2590.85
# steps: 2839, all step: 2019028
# 5317 episode score is 2568.11
# steps: 2573, all step: 2021601
# 5322 episode score is 1831.98
# steps: 2264, all step: 2023865
# 5326 episode score is 2074.97
# steps: 2394, all step: 2026259
# 5332 episode score is 1477.51
# steps: 2164, all step: 2028423
# 5335 episode score is 2575.73
# steps: 2521, all step: 2030944
# 5338 episode score is 3035.44
# steps: 2381, all step: 2033325
# 5341 episode score is 2894.24
# steps: 2166, all step: 2035491
# 5346 episode score is 1582.35
# steps: 2553, all step: 2038044
# 5349 episode score is 3018.48
# steps: 2759, all step: 2040803
# 5353 episode score is 2493.68
# steps: 2110, all step: 2042913
# 5356 episode score is 2520.63
# steps: 2993, all step: 2045906
# 5360 episode score is 2690.64
# steps: 2183, all step: 2048089
# 5366 episode score is 1312.55
# steps: 3032, all step: 2051121
# 5370 episode score is 2712.96
# steps: 2404, all step: 2053525
# 5374 episode score is 2208.51
# steps: 2921, all step: 2056446
# 5378 episode score is 2652.70
# steps: 2160, all step: 2058606
# 5381 episode score is 2647.16
# steps: 2330, all step: 2060936
# 5385 episode score is 2146.99
# steps: 2079, all step: 2063015
# 5389 episode score is 1892.75
# steps: 2188, all step: 2065203
# 5394 episode score is 1604.06
# steps: 2246, all step: 2067449
# 5398 episode score is 2021.55
# steps: 2773, all step: 2070222
# 5402 episode score is 2543.92
# steps: 2443, all step: 2072665
# 5405 episode score is 2946.41
# steps: 2831, all step: 2075496
# 5410 episode score is 2035.36
# steps: 2289, all step: 2077785
# 5414 episode score is 2093.81
# steps: 2465, all step: 2080250
# 5417 episode score is 2984.71
# steps: 2979, all step: 2083229
# 5422 episode score is 2151.49
# steps: 2427, all step: 2085656
# 5425 episode score is 2916.79
# steps: 2330, all step: 2087986
# 5428 episode score is 2801.01
# steps: 2242, all step: 2090228
# 5432 episode score is 1993.79
# steps: 2659, all step: 2092887
# 5436 episode score is 2375.16
# steps: 2165, all step: 2095052
# 5440 episode score is 1976.99
# steps: 2150, all step: 2097202
# 5444 episode score is 1949.48
# steps: 2374, all step: 2099576
# 5449 episode score is 1683.46
# steps: 2320, all step: 2101896
# 5454 episode score is 1682.34
# steps: 2821, all step: 2104717
# 5459 episode score is 2066.67
# steps: 2068, all step: 2106785
# 5463 episode score is 1835.05
# steps: 2341, all step: 2109126
# 5467 episode score is 2094.73
# steps: 2627, all step: 2111753
# 5472 episode score is 1914.74
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-b85707df7bff> in <module>()
#      62     print('{} episode score is {:.2f}'.format(episodes, score_avg))
#      63     ppo_agent.actor.train(), ppo_agent.critic.train()
# ---> 64     ppo_agent.train_model(memory)
#      65
#      66 # ppo_agent.actor.eval(), ppo_agent.critic.eval()
#
# <ipython-input-66-fb59a4fb74df> in train_model(self, memory)
#      38         # ----------------------------
#      39         # step 1: get returns and GAEs and log probability of old policy
# ---> 40         returns, advants = self.get_gae(rewards, masks, values)
#      41         mu, std, logstd = self.actor(states)
#      42         old_policy = self.log_density(actions, mu, std, logstd).detach()
#
# <ipython-input-66-fb59a4fb74df> in get_gae(self, rewards, masks, values)
#      81
#      82         for t in reversed(range(0, len(rewards))):
# ---> 83             running_returns = rewards[t] + self.gamma * running_returns * masks[t]
#      84             running_tderror = rewards[t] + self.gamma * previous_value * masks[t] - values.data[t]
#      85             running_advants = running_tderror + self.gamma * self.lamda * running_advants * masks[t]
#
# KeyboardInterrupt:
